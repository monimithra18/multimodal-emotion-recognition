# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nlp-tweet-sentiment-analysis/bitcointweets.csv

# %%
import os
import cv2
import glob
import os.path
import skimage
import numpy as np
import pandas as pd
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
from keras.models import Sequential
from skimage.transform import resize
from keras.callbacks import ModelCheckpoint
from keras.models import load_model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split
from keras.layers import Dense,Embedding,Conv1D,MaxPooling1D,LSTM
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from keras.applications.inception_resnet_v2 import preprocess_input, decode_predictions

# %%
df = pd.read_csv('/kaggle/input/nlp-tweet-sentiment-analysis/bitcointweets.csv', header=None)

# %%
df.head()
# Out:
#                                 0  \
# 0  Fri Mar 23 00:40:32 +0000 2018
# 1  Fri Mar 23 00:40:34 +0000 2018
# 2  Fri Mar 23 00:40:35 +0000 2018
# 3  Fri Mar 23 00:40:36 +0000 2018
# 4  Fri Mar 23 00:40:36 +0000 2018
#
#                                                    1               2      3  \
# 0  RT @ALXTOKEN: Paul Krugman, Nobel Luddite. I h...  myresumerocket  16522
# 1  @lopp @_Kevin_Pham @psycho_sage @naval But @Pr...        BitMocro   1295
# 2  RT @tippereconomy: Another use case for #block...    hojachotopur   6090
# 3                 free coins https://t.co/DiuoePJdap   denies_distro   2626
# 4  RT @payvxofficial: WE are happy to announce th...      aditzgraha    184
#
#    4                                             5  \
# 0  0                                            []
# 1  0                                  [u'Bitcoin']
# 2  0  [u'blockchain', u'Tipper', u'TipperEconomy']
# 3  0                                            []
# 4  0                                            []
#
#                                                    6             7
# 0  <a href="http://twitter.com" rel="nofollow">Tw...   ['neutral']
# 1  <a href="http://twitter.com/download/android" ...   ['neutral']
# 2  <a href="http://twitter.com" rel="nofollow">Tw...  ['positive']
# 3  <a href="http://twitter.com" rel="nofollow">Tw...  ['positive']
# 4  <a href="http://twitter.com/download/android" ...  ['positive']

# %%
df.describe()
# Out:
#                   3        4
# count  5.085900e+04  50859.0
# mean   5.200523e+03      0.0
# std    6.538524e+04      0.0
# min    0.000000e+00      0.0
# 25%    5.500000e+01      0.0
# 50%    3.930000e+02      0.0
# 75%    2.027000e+03      0.0
# max    1.019444e+07      0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50859 entries, 0 to 50858
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       50859 non-null  object
#  1   1       50859 non-null  object
#  2   2       50859 non-null  object
#  3   3       50859 non-null  int64
#  4   4       50859 non-null  int64
#  5   5       50859 non-null  object
#  6   6       50859 non-null  object
#  7   7       50859 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.1+ MB

# %%
df.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
# Select the relevant columns for analysis
df = df.iloc[:, [1, 7]]

# Rename the columns for clarity
df.columns = ['tweet', 'label']

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                                tweet         label
# 0  RT @ALXTOKEN: Paul Krugman, Nobel Luddite. I h...   ['neutral']
# 1  @lopp @_Kevin_Pham @psycho_sage @naval But @Pr...   ['neutral']
# 2  RT @tippereconomy: Another use case for #block...  ['positive']
# 3                 free coins https://t.co/DiuoePJdap  ['positive']
# 4  RT @payvxofficial: WE are happy to announce th...  ['positive']

# %%
df.label.unique()
# Out:
# array(["['neutral']", "['positive']", "['negative']"], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each label
label_counts = df['label'].value_counts()

# Set the style for the plot
sns.set(style="darkgrid")

# Bar Graph
plt.figure(figsize=(10, 6))
label_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Labels in the Dataset', fontsize=16)
plt.xlabel('Sentiment Labels', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each label
label_counts = df['label'].value_counts()

# Set the style for the plot
sns.set(style="darkgrid")

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Distribution of Labels in the Dataset', fontsize=16)
plt.show()

# %% [markdown]
# # Before Cleaning TEXT

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df[df['label'] == "['neutral']"]['tweet'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the word cloud with the corresponding label class
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'Word Cloud for Label: {label_class}', fontsize=16)
plt.show()

# %%
text = " ".join(df[df['label'] == "['positive']"]['tweet'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the word cloud with the corresponding label class
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'Word Cloud for Label: {label_class}', fontsize=16)
plt.show()

# %%
text = " ".join(df[df['label'] == "['neutral']"]['tweet'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the word cloud with the corresponding label class
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'Word Cloud for Label: {label_class}', fontsize=16)
plt.show()

# %% [markdown]
# # Lets perform some cleaning on dataset as we can see it is very noisy data

# %%
# !pip install demoji
# Out:
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
import re
import string
import demoji
from nltk.corpus import stopwords
from wordcloud import WordCloud

# Download the demoji library data
demoji.download_codes()

# Define a function to clean the text data
def clean_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    
    # Remove retweet tags and mentions
    text = re.sub('(RT|via)((?:\\b\\W*@\\w+)+)', ' ', text)
    text = re.sub(r'@\S+', '', text)
    
    # Remove emojis
    text = demoji.replace(text, '')
    
    # Remove special characters and symbols
    text = re.sub(r'[^\w\s]', '', text)
    
    # Convert all text to lowercase
    text = text.lower()
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    
    # Remove any remaining noise
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    return text

# Apply the cleaning function to the 'text_data' column and generate a word cloud
df['cleaned_text'] = df['tweet'].apply(clean_text)  # Replace 'text_data' with your desired column name
# Out:
# /tmp/ipykernel_32/3750509795.py:8: FutureWarning: The demoji.download_codes attribute is deprecated and will be removed from demoji in a future version. It is an unused attribute as emoji codes are now distributed directly with the demoji package.
#   demoji.download_codes()

# %%
df.head()
# Out:
#                                                tweet         label  \
# 0  RT @ALXTOKEN: Paul Krugman, Nobel Luddite. I h...   ['neutral']
# 1  @lopp @_Kevin_Pham @psycho_sage @naval But @Pr...   ['neutral']
# 2  RT @tippereconomy: Another use case for #block...  ['positive']
# 3                 free coins https://t.co/DiuoePJdap  ['positive']
# 4  RT @payvxofficial: WE are happy to announce th...  ['positive']
#
#                                         cleaned_text
# 0  paul krugman nobel luddite tweak nose bitcoin ...
# 1                 dum b ss said know nothing bitcoin
# 2  another use case blockchain tipper tipperecono...
# 3                                         free coins
# 4  happy announce payvx presale phase 1 live sign...

# %%
# Encode Categorical Variable
X = df['cleaned_text']  # Replace 'clean_tweet' with 'cleaned_text' for clarity
y = pd.get_dummies(df['label']).values
num_classes = df['label'].nunique()

# %%
num_classes
# Out:
# 3

# %%
X.head()
# Out:
# 0    paul krugman nobel luddite tweak nose bitcoin ...
# 1                   dum b ss said know nothing bitcoin
# 2    another use case blockchain tipper tipperecono...
# 3                                           free coins
# 4    happy announce payvx presale phase 1 live sign...
# Name: cleaned_text, dtype: object

# %%
y[:10]
# Out:
# array([[False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True]])

# %%
# Split Train Test sets
from sklearn.model_selection import train_test_split

# Concatenate X and y for the split
data = pd.concat([X, pd.DataFrame(y)], axis=1)

# Perform the split
train, test = train_test_split(data, test_size=0.2, stratify=y, random_state=42)

# Separate X_train, X_test, y_train, y_test
X_train, y_train = train['cleaned_text'], train.drop('cleaned_text', axis=1)
X_test, y_test = test['cleaned_text'], test.drop('cleaned_text', axis=1)

# %%
X_train.shape,  y_train.shape
# Out:
# ((40687,), (40687, 3))

# %%
X_test.shape, y_test.shape
# Out:
# ((10172,), (10172, 3))

# %%
import matplotlib.pyplot as plt

# Assuming Y_train is a one-hot encoded array
label_counts_train = y_train.sum(axis=0)
label_counts_test = y_test.sum(axis=0)

# Plotting the bar graph
fig, ax = plt.subplots()
index = range(3)
bar_width = 0.35

rects1 = ax.bar(index, label_counts_train, bar_width, label='Train')
rects2 = ax.bar([i + bar_width for i in index], label_counts_test, bar_width, label='Test')

ax.set_xlabel('Categories')
ax.set_ylabel('Counts')
ax.set_title('Count of Labels in Train and Test Data')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(["['neutral']", "['positive']", "['negative']"])
ax.legend()

plt.show()

# %%
from keras.preprocessing.text import Tokenizer

# Set the maximum number of features
max_features = 20000

# Initialize the Tokenizer
tokenizer = Tokenizer(num_words=max_features, oov_token='<OOV>')  # Setting the out-of-vocabulary token

# Fit the Tokenizer on the training data
try:
    tokenizer.fit_on_texts(X_train)  # Fit the Tokenizer on the training data
except Exception as e:
    print(f"An error occurred during Tokenizer fitting: {e}")

# Convert the text data to sequences for both training and testing sets
try:
    X_train_sequences = tokenizer.texts_to_sequences(X_train)  # Convert training data to sequences
    X_test_sequences = tokenizer.texts_to_sequences(X_test)  # Convert testing data to sequences
except Exception as e:
    print(f"An error occurred during text to sequences conversion: {e}")

# %%
X_train_sequences[:10]
# Out:
# [[239, 174, 88, 239, 1402, 88],
#  [44, 48, 46, 50, 76, 7, 81],
#  [2833, 383, 3266, 7899, 1830, 2735, 3267, 3268, 2952, 4983],
#  [2326, 144, 440, 125, 298, 449, 5619, 67, 643, 298, 6, 5, 8, 22, 328, 2],
#  [174, 359, 88, 529, 20, 553, 768, 806, 13, 649, 834, 311, 210, 105, 420, 812],
#  [397, 293, 434, 402, 226, 256, 443, 2, 15, 412, 2],
#  [643, 7900, 2, 55, 567, 1028, 11015, 539, 976, 3900, 977, 11016],
#  [1890, 1403, 7901, 2, 7902, 7, 7903, 2, 7, 184, 191, 3, 6],
#  [9, 4, 11017, 187, 9, 4, 47, 126, 7904, 54, 4169],
#  [17, 37, 64, 70, 2, 17, 78]]

# %%
from tensorflow.keras.preprocessing import sequence

max_words = 30

# Apply padding to the sequences
try:
    X_train_padded = sequence.pad_sequences(X_train_sequences, maxlen=max_words, padding='post', truncating='post')  # Apply padding to training sequences
    X_test_padded = sequence.pad_sequences(X_test_sequences, maxlen=max_words, padding='post', truncating='post')  # Apply padding to testing sequences
except Exception as e:
    print(f"An error occurred during sequence padding: {e}")

print(X_train_padded.shape, X_test_padded.shape)
# Out:
# (40687, 30) (10172, 30)

# %%
from tensorflow import keras
from tensorflow.keras import layers

max_features = 20000
embed_dim = 100

K.clear_session()
model = keras.Sequential()

# Embedding Layer
model.add(layers.Embedding(max_features, embed_dim, input_length=X_train_padded.shape[1]))

# Convolutional Layers
model.add(layers.Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Conv1D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(layers.MaxPooling1D(pool_size=2))

# LSTM Layer
model.add(layers.LSTM(100, return_sequences=True))
model.add(layers.LSTM(100))

# Fully Connected Layers
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))

# Output Layer
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 30, 100)           2000000
#
#  conv1d (Conv1D)             (None, 30, 64)            19264
#
#  max_pooling1d (MaxPooling1D  (None, 15, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 15, 128)           24704
#
#  max_pooling1d_1 (MaxPooling  (None, 7, 128)           0
#  1D)
#
#  lstm (LSTM)                 (None, 7, 100)            91600
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 256)               25856
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,275,107
# Trainable params: 2,275,107
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

# Plot the model architecture as a PNG image
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(filepath='best_model.h5',
                                  monitor='val_accuracy',
                                  save_best_only=True,
                                  mode='max',
                                  verbose=1)

# %%
# Train the model with the ModelCheckpoint callback
training_history = model.fit(X_train_padded, y_train,
                                batch_size=64,
                                epochs=100,
                                shuffle=True,
                                validation_data=(X_test_padded, y_test),
                                callbacks=[model_checkpoint],
                                verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 1: val_accuracy improved from -inf to 0.96638, saving model to best_model.h5
# 636/636 - 35s - loss: 0.2834 - accuracy: 0.8862 - val_loss: 0.1200 - val_accuracy: 0.9664 - 35s/epoch - 55ms/step
# Epoch 2/100
#
# Epoch 2: val_accuracy improved from 0.96638 to 0.97149, saving model to best_model.h5
# 636/636 - 9s - loss: 0.0665 - accuracy: 0.9805 - val_loss: 0.1032 - val_accuracy: 0.9715 - 9s/epoch - 14ms/step
# Epoch 3/100
#
# Epoch 3: val_accuracy did not improve from 0.97149
# 636/636 - 7s - loss: 0.0331 - accuracy: 0.9905 - val_loss: 0.1294 - val_accuracy: 0.9679 - 7s/epoch - 11ms/step
# Epoch 4/100
#
# Epoch 4: val_accuracy did not improve from 0.97149
# 636/636 - 7s - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.1512 - val_accuracy: 0.9617 - 7s/epoch - 11ms/step
# Epoch 5/100
#
# Epoch 5: val_accuracy did not improve from 0.97149
# 636/636 - 6s - loss: 0.0169 - accuracy: 0.9956 - val_loss: 0.1373 - val_accuracy: 0.9702 - 6s/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_accuracy did not improve from 0.97149
# 636/636 - 6s - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.1626 - val_accuracy: 0.9690 - 6s/epoch - 9ms/step
# Epoch 7/100
#
# Epoch 7: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.1387 - val_accuracy: 0.9683 - 5s/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.1913 - val_accuracy: 0.9628 - 5s/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.2272 - val_accuracy: 0.9677 - 5s/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.97149
# 636/636 - 6s - loss: 0.0070 - accuracy: 0.9985 - val_loss: 0.2764 - val_accuracy: 0.9674 - 6s/epoch - 9ms/step
# Epoch 11/100
#
# Epoch 11: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.1500 - val_accuracy: 0.9654 - 5s/epoch - 8ms/step
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.2281 - val_accuracy: 0.9651 - 5s/epoch - 8ms/step
# Epoch 13/100
#
# Epoch 13: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.1984 - val_accuracy: 0.9672 - 5s/epoch - 8ms/step
# Epoch 14/100
#
# Epoch 14: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.2203 - val_accuracy: 0.9665 - 5s/epoch - 8ms/step
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.2598 - val_accuracy: 0.9660 - 5s/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.2521 - val_accuracy: 0.9678 - 5s/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.3945 - val_accuracy: 0.9668 - 5s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_accuracy did not improve from 0.97149
# 636/636 - 6s - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.1958 - val_accuracy: 0.9679 - 6s/epoch - 9ms/step
# Epoch 19/100
#
# Epoch 19: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.3834 - val_accuracy: 0.9643 - 5s/epoch - 8ms/step
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.2958 - val_accuracy: 0.9669 - 5s/epoch - 8ms/step
# Epoch 21/100
#
# Epoch 21: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.3007 - val_accuracy: 0.9672 - 5s/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3884 - val_accuracy: 0.9680 - 5s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.3403 - val_accuracy: 0.9664 - 5s/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2515 - val_accuracy: 0.9680 - 5s/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.4005 - val_accuracy: 0.9673 - 5s/epoch - 8ms/step
# Epoch 26/100
#
# Epoch 26: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.4606 - val_accuracy: 0.9675 - 5s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.3232 - val_accuracy: 0.9685 - 5s/epoch - 8ms/step
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.3327 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 29/100
#
# Epoch 29: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.2953 - val_accuracy: 0.9684 - 5s/epoch - 8ms/step
# Epoch 30/100
#
# Epoch 30: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.2778 - val_accuracy: 0.9688 - 5s/epoch - 8ms/step
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.2803 - val_accuracy: 0.9672 - 5s/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.3946 - val_accuracy: 0.9699 - 5s/epoch - 8ms/step
# Epoch 33/100
#
# Epoch 33: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.6436 - val_accuracy: 0.9673 - 5s/epoch - 8ms/step
# Epoch 34/100
#
# Epoch 34: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.4348 - val_accuracy: 0.9667 - 5s/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.4746 - val_accuracy: 0.9691 - 5s/epoch - 8ms/step
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.3359 - val_accuracy: 0.9687 - 5s/epoch - 8ms/step
# Epoch 37/100
#
# Epoch 37: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.4762 - val_accuracy: 0.9678 - 5s/epoch - 8ms/step
# Epoch 38/100
#
# Epoch 38: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.3326 - val_accuracy: 0.9679 - 5s/epoch - 8ms/step
# Epoch 39/100
#
# Epoch 39: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.3887 - val_accuracy: 0.9666 - 5s/epoch - 7ms/step
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.6048 - val_accuracy: 0.9677 - 5s/epoch - 8ms/step
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.3739 - val_accuracy: 0.9645 - 5s/epoch - 7ms/step
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.5071 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.9524 - val_accuracy: 0.9685 - 5s/epoch - 8ms/step
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.4475 - val_accuracy: 0.9693 - 5s/epoch - 8ms/step
# Epoch 45/100
#
# Epoch 45: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.3997 - val_accuracy: 0.9686 - 5s/epoch - 8ms/step
# Epoch 46/100
#
# Epoch 46: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.4375 - val_accuracy: 0.9667 - 5s/epoch - 7ms/step
# Epoch 47/100
#
# Epoch 47: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.5123 - val_accuracy: 0.9698 - 5s/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.5144 - val_accuracy: 0.9698 - 5s/epoch - 8ms/step
# Epoch 49/100
#
# Epoch 49: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.2989 - val_accuracy: 0.9651 - 5s/epoch - 8ms/step
# Epoch 50/100
#
# Epoch 50: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.2903 - val_accuracy: 0.9678 - 5s/epoch - 8ms/step
# Epoch 51/100
#
# Epoch 51: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2839 - val_accuracy: 0.9668 - 5s/epoch - 8ms/step
# Epoch 52/100
#
# Epoch 52: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.3314 - val_accuracy: 0.9676 - 5s/epoch - 8ms/step
# Epoch 53/100
#
# Epoch 53: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.4132 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 54/100
#
# Epoch 54: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.4101 - val_accuracy: 0.9680 - 5s/epoch - 7ms/step
# Epoch 55/100
#
# Epoch 55: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.3728 - val_accuracy: 0.9680 - 5s/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.4049 - val_accuracy: 0.9675 - 5s/epoch - 8ms/step
# Epoch 57/100
#
# Epoch 57: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.4043 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 58/100
#
# Epoch 58: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.3291 - val_accuracy: 0.9692 - 5s/epoch - 8ms/step
# Epoch 59/100
#
# Epoch 59: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.3041 - val_accuracy: 0.9677 - 5s/epoch - 8ms/step
# Epoch 60/100
#
# Epoch 60: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.4033 - val_accuracy: 0.9689 - 5s/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.2609 - val_accuracy: 0.9683 - 5s/epoch - 7ms/step
# Epoch 62/100
#
# Epoch 62: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.3548 - val_accuracy: 0.9678 - 5s/epoch - 7ms/step
# Epoch 63/100
#
# Epoch 63: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.4085 - val_accuracy: 0.9686 - 5s/epoch - 8ms/step
# Epoch 64/100
#
# Epoch 64: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.4207 - val_accuracy: 0.9680 - 5s/epoch - 8ms/step
# Epoch 65/100
#
# Epoch 65: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.2982 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 66/100
#
# Epoch 66: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.5125 - val_accuracy: 0.9701 - 5s/epoch - 7ms/step
# Epoch 67/100
#
# Epoch 67: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.4527 - val_accuracy: 0.9680 - 5s/epoch - 7ms/step
# Epoch 68/100
#
# Epoch 68: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.4835 - val_accuracy: 0.9683 - 5s/epoch - 8ms/step
# Epoch 69/100
#
# Epoch 69: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.4724 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 70/100
#
# Epoch 70: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.4801 - val_accuracy: 0.9675 - 5s/epoch - 8ms/step
# Epoch 71/100
#
# Epoch 71: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.5472 - val_accuracy: 0.9675 - 5s/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.8261 - val_accuracy: 0.9680 - 5s/epoch - 8ms/step
# Epoch 73/100
#
# Epoch 73: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.4422 - val_accuracy: 0.9690 - 5s/epoch - 8ms/step
# Epoch 74/100
#
# Epoch 74: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.3174 - val_accuracy: 0.9702 - 5s/epoch - 7ms/step
# Epoch 75/100
#
# Epoch 75: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.4484 - val_accuracy: 0.9703 - 5s/epoch - 8ms/step
# Epoch 76/100
#
# Epoch 76: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.3406 - val_accuracy: 0.9688 - 5s/epoch - 8ms/step
# Epoch 77/100
#
# Epoch 77: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.4076 - val_accuracy: 0.9672 - 5s/epoch - 8ms/step
# Epoch 78/100
#
# Epoch 78: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.5393 - val_accuracy: 0.9666 - 5s/epoch - 7ms/step
# Epoch 79/100
#
# Epoch 79: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.5804 - val_accuracy: 0.9670 - 5s/epoch - 7ms/step
# Epoch 80/100
#
# Epoch 80: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.4706 - val_accuracy: 0.9672 - 5s/epoch - 8ms/step
# Epoch 81/100
#
# Epoch 81: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.6241 - val_accuracy: 0.9685 - 5s/epoch - 7ms/step
# Epoch 82/100
#
# Epoch 82: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.5597 - val_accuracy: 0.9685 - 5s/epoch - 8ms/step
# Epoch 83/100
#
# Epoch 83: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.6737 - val_accuracy: 0.9682 - 5s/epoch - 8ms/step
# Epoch 84/100
#
# Epoch 84: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.7191 - val_accuracy: 0.9686 - 5s/epoch - 8ms/step
# Epoch 85/100
#
# Epoch 85: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.7533 - val_accuracy: 0.9686 - 5s/epoch - 8ms/step
# Epoch 86/100
#
# Epoch 86: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.7583 - val_accuracy: 0.9678 - 5s/epoch - 8ms/step
# Epoch 87/100
#
# Epoch 87: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.7864 - val_accuracy: 0.9686 - 5s/epoch - 7ms/step
# Epoch 88/100
#
# Epoch 88: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.7108 - val_accuracy: 0.9673 - 5s/epoch - 8ms/step
# Epoch 89/100
#
# Epoch 89: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.4898 - val_accuracy: 0.9687 - 5s/epoch - 8ms/step
# Epoch 90/100
#
# Epoch 90: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.3642 - val_accuracy: 0.9605 - 5s/epoch - 8ms/step
# Epoch 91/100
#
# Epoch 91: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.4338 - val_accuracy: 0.9689 - 5s/epoch - 8ms/step
# Epoch 92/100
#
# Epoch 92: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5048 - val_accuracy: 0.9686 - 5s/epoch - 8ms/step
# Epoch 93/100
#
# Epoch 93: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.4425 - val_accuracy: 0.9690 - 5s/epoch - 8ms/step
# Epoch 94/100
#
# Epoch 94: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.5041 - val_accuracy: 0.9694 - 5s/epoch - 7ms/step
# Epoch 95/100
#
# Epoch 95: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.7837 - val_accuracy: 0.9684 - 5s/epoch - 8ms/step
# Epoch 96/100
#
# Epoch 96: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.5141 - val_accuracy: 0.9698 - 5s/epoch - 8ms/step
# Epoch 97/100
#
# Epoch 97: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.4659 - val_accuracy: 0.9689 - 5s/epoch - 7ms/step
# Epoch 98/100
#
# Epoch 98: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.4557 - val_accuracy: 0.9689 - 5s/epoch - 8ms/step
# Epoch 99/100
#
# Epoch 99: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.4714 - val_accuracy: 0.9694 - 5s/epoch - 8ms/step
# Epoch 100/100
#
# Epoch 100: val_accuracy did not improve from 0.97149
# 636/636 - 5s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.4828 - val_accuracy: 0.9692 - 5s/epoch - 7ms/step

# %%
# Setting the plot style
plt.style.use('dark_background')

# Plotting the accuracy
plt.figure(figsize=(8, 6))
plt.plot(training_history.history['accuracy'], label='Training Accuracy', color='lightblue', linestyle='dashed', linewidth=2)
plt.plot(training_history.history['val_accuracy'], label='Validation Accuracy', color='salmon', linestyle='dotted', linewidth=2)
plt.title('Model Accuracy', fontsize=15, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.show()

# %%
# Plotting the loss
plt.figure(1)
plt.plot(training_history.history['loss'], label='training loss')  # Changed 'history' to 'training_history'
plt.plot(training_history.history['val_loss'], label='validation loss')  # Changed 'history' to 'training_history'
plt.title('Model Loss')  # Modified the title
plt.xlabel('Epochs')  # Modified the x-label
plt.ylabel('Loss')  # Modified the y-label
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score

y_predicted = model.predict(X_test_padded)
y_predicted = (y_predicted > 0.45)
accuracy = accuracy_score(y_predicted, y_test)
print("Accuracy with test data: ", accuracy * 100, "%")
# Out:
# 318/318 [==============================] - 2s 3ms/step
# Accuracy with test data:  96.88360204482895 %

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      1197
#            1       0.96      0.98      0.97      4388
#            2       0.98      0.97      0.98      4587
#
#    micro avg       0.97      0.97      0.97     10172
#    macro avg       0.97      0.95      0.96     10172
# weighted avg       0.97      0.97      0.97     10172
#  samples avg       0.97      0.97      0.97     10172
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Serialize the model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# Serialize weights to HDF5
model.save_weights("model_weights.h5")
model.save('model.h5')

import pickle

# Saving the tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Loading the tokenizer (for example)
with open('tokenizer.pickle', 'rb') as handle:
    loaded_tokenizer = pickle.load(handle)

loaded_model = load_model('model.h5')

def preprocess_text(comment):
    # Add the same preprocessing steps you applied to the training data
    clean_comment = clean_text(comment)
    tokenized_comment = loaded_tokenizer.texts_to_sequences([clean_comment])
    padded_comment = sequence.pad_sequences(tokenized_comment, maxlen=max_words)
    return padded_comment

def make_prediction(comment, model):
    preprocessed_comment = preprocess_text(comment)
    prediction = np.argmax(loaded_model.predict(preprocessed_comment), axis=1)
    if prediction == 0:
        return "Negative"
    elif prediction == 1:
        return "Neutral"
    elif prediction == 2:
        return "Positive"
    else:
        return "Unknown"

# %%
# Example usage of the function
comment_to_predict = "This is a great day."
prediction_result = make_prediction(comment_to_predict, model)
print("The sentiment prediction for the comment is:", prediction_result)
# Out:
# 1/1 [==============================] - 1s 770ms/step
# The sentiment prediction for the comment is: Neutral

# %%
# Example usage of the function
comment_to_predict = "This is a great day. Feeling good and happy"
prediction_result = make_prediction(comment_to_predict, model)
print("The sentiment prediction for the comment is:", prediction_result)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# The sentiment prediction for the comment is: Positive

# %%
# Example usage of the function
comment_to_predict = "Not feeling well today; it's a very bad and disgusting day."
prediction_result = make_prediction(comment_to_predict, model)
print("The sentiment prediction for the comment is:", prediction_result)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# The sentiment prediction for the comment is: Negative
